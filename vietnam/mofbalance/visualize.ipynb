# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.DataFrame(pd.read_csv('https://raw.githubusercontent.com/thanhqtran/dataset/6fb7255cb089ba11f4f9f0b18f0d1d65ae6a49b6/vietnam/mofbalance/state_budget_balance.csv'))
# delete legends columns
df = data.drop(['Classification','item_VN','item'], axis=1)
# convert data to long form 
df
df_melted = df.melt(id_vars=['Code'], value_vars=[ year for year in df.columns[1:] ])
df_melted
# Out:
#              Code variable       value
# 0     agg_tax_cor     2001     35574.0
# 1     tax_cor_soe     2001     23149.0
# 2     tax_cor_fdi     2001      5702.0
# 3    tax_cor_priv     2001      6723.0
# 4         tax_inc     2001      2058.0
# ..            ...      ...         ...
# 869    agg_invExp     2019    421845.0
# 870       agg_Exp     2019   1526983.0
# 871           def     2019    161491.0
# 872      gdp_curr     2019  6048352.06
# 873     rgdp_cons     2019         NaN
#
# [874 rows x 3 columns]

# %%
df
# Out:
#             Code      2001      2002      2003      2004       2005     2006  \
# 0    agg_tax_cor   35574.0   40106.0   47410.0   56987.0    75847.0   99796
# 1    tax_cor_soe   23149.0   25066.0   28748.0   13066.0    15017.0    21018
# 2    tax_cor_fdi    5702.0    7276.0    9942.0   37512.0    52834.0    68734
# 3   tax_cor_priv    6723.0    7764.0   10361.0    6409.0     7906.0    10045
# 4        tax_inc    2058.0    2338.0    2951.0    3521.0     4234.0    5179
# 5        tax_res     298.0     336.0     359.0     438.0      515.0     594
# 6        tax_reg    1191.0    1332.0    1817.0    2607.0     2797.0    3363
# 7        tax_vat       NaN    9488.0   33130.0   38814.0    45878.0   55148
# 8        tax_exc       NaN       NaN    8851.0   12773.0    15716.0   17195
# 9        tax_nat       NaN       NaN    9719.0   17398.0    21236.0   26620
# 10       tax_agr     814.0     772.0     151.0     130.0      132.0     111
# ...

# %%
# figure of agg_Exp and agg_Rev
inquiry = df_melted[df_melted['Code'] == 'agg_Exp']
inquiry2 = df_melted[df_melted['Code'] == 'agg_Rev']
inquiry3 = df_melted[df_melted['Code'] == 'def']
plt.plot(inquiry['variable'], inquiry['value'].astype(float)/1000, label='Aggregate Expenditure')
plt.plot(inquiry2['variable'], inquiry2['value'].astype(float)/1000, label='Aggregate Revenue')
plt.plot(inquiry3['variable'], inquiry3['value'].astype(float)/1000, label='Deficit', color='red', linestyle=':')
plt.ylabel('1000 Bil. VND')
plt.xlabel('Year')
plt.xticks(rotation=90)
plt.legend()
plt.title('Vietnamese Government Budget Balance')
